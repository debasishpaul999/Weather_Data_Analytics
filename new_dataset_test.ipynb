# %%
import pandas as pd

# %%
df = pd.read_csv("Data/Calcutta/weather_data_2005.csv")

# %%
df
# Out:
#            time  temperature_2m_max  temperature_2m_min  \
# 0    2005-01-01                25.8                14.2
# 1    2005-01-02                26.1                14.6
# 2    2005-01-03                26.9                15.5
# 3    2005-01-04                26.2                17.8
# 4    2005-01-05                26.9                16.1
# ..          ...                 ...                 ...
# 360  2005-12-27                25.2                11.4
# 361  2005-12-28                25.2                11.5
# 362  2005-12-29                25.7                13.5
# 363  2005-12-30                25.4                12.2
# 364  2005-12-31                25.1                11.5
#
#      apparent_temperature_max  apparent_temperature_min  rain_sum  \
# 0                        26.1                      13.7       0.0
# 1                        27.9                      15.6       0.0
# 2                        28.5                      16.8       0.0
# ...
